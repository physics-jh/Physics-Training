# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/PJH/OneDrive/GIT/RC_filter_data.csv')

# %%
t = df['t']
V_in = df['V_in']
V_f = df['V_f']

# %%
fig, ax = plt.subplots()
ax.plot(t,V_in, label='V_in')
ax.plot(t,V_f, label='V_f')
ax.legend()
ax.grid()
plt.show()
